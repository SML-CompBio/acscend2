# %%
#Fig 4 E, F

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# Function to apply log2 normalization to the raw counts
def log2_normalize(counts):
    return np.log2(counts + 1)


import os
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.axisartist.axislines import Axes

# Path to the folder containing the 5 train folders
base_path = "C:\\Users\\HP\\Downloads\\Development\\Development\\"

# Folder names
folders = ["1 train", "2 train", "3 train", "4 train", "5 train"]

# File names corresponding to the epoch_ccc and epoch_rmse files in each folder
file_names_ccc = ["epoch_ccc1.csv", "epoch_ccc2.csv", "epoch_ccc3.csv", "epoch_ccc4.csv", "epoch_ccc5.csv"]
file_names_rmse = ["epoch_rmse1.csv", "epoch_rmse2.csv", "epoch_rmse3.csv", "epoch_rmse4.csv", "epoch_rmse5.csv"]
file_names_val = ["epoch_val_loss1.csv", "epoch_val_loss2.csv", "epoch_val_loss3.csv", "epoch_val_loss4.csv", "epoch_val_loss5.csv"]

# Plot labels
plot_labels_ccc = ["CCC1", "CCC2", "CCC3", "CCC4", "CCC5"]
plot_labels_rmse = ["RMSE1", "RMSE2", "RMSE3", "RMSE4", "RMSE5"]
plot_labels_val = ["Val_loss1", "Val_loss2", "Val_loss3", "Val_loss4", "Val_loss5"]

# Colorblind-friendly colors
colors_ccc = ['maroon', 'coral', 'goldenrod', 'teal', 'mediumvioletred']
colors_rmse = ['maroon', 'coral', 'goldenrod', 'teal', 'mediumvioletred']
colors_val = ['maroon', 'coral', 'goldenrod', 'teal', 'mediumvioletred']

# Create a new figure for CCC
plt.figure(figsize=(6, 6))

# Iterate over each folder and corresponding file to extract and plot "per epoch ccc" values
for i, (folder, file_name) in enumerate(zip(folders, file_names_ccc)):
    file_path = os.path.join(base_path, folder, file_name)
    
    # Read the CSV into a dataframe
    df = pd.read_csv(file_path)
    
    # Extract the first column (epoch) and second column (per epoch ccc)
    if df.shape[1] >= 2:  # Ensure there are at least two columns
        epochs = df.iloc[:, 0].values  # First column is 'epoch'
        ccc_values = df.iloc[:, 1].values  # Second column is 'per epoch ccc'
        
        # Plot the 'per epoch ccc' values against 'epoch'
        plt.plot(epochs, ccc_values, label=plot_labels_ccc[i], color=colors_ccc[i], linewidth=2)

# Add labels and legend for CCC
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('CCC Value', fontsize=20)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
y_min, y_max = plt.ylim()
plt.gca().spines['left'].set_bounds(y_min, y_max)
plt.gca().spines['bottom'].set_bounds(0, 100)

# Increase tick label size
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
plt.tight_layout(pad=2)
# Save the CCC plot
#plt.savefig("C:\\Users\\HP\\Desktop\\New Ascend Results\\Mouse\\CCC_plot.png", dpi = 1200)  # Update the path as needed

# Display the CCC plot
plt.show()

# Create a new figure for RMSE
plt.figure(figsize=(6, 6))

# Iterate over each folder and corresponding file to extract and plot "per epoch rmse" values
for i, (folder, file_name) in enumerate(zip(folders, file_names_rmse)):
    file_path = os.path.join(base_path, folder, file_name)
    
    # Read the CSV into a dataframe
    df = pd.read_csv(file_path)
    
    # Extract the first column (epoch) and second column (per epoch rmse)
    if df.shape[1] >= 2:  # Ensure there are at least two columns
        epochs = df.iloc[:, 0].values  # First column is 'epoch'
        rmse_values = df.iloc[:, 1].values  # Second column is 'per epoch rmse'
        
        # Plot the 'per epoch rmse' values against 'epoch'
        plt.plot(epochs, rmse_values, label=plot_labels_rmse[i], color=colors_rmse[i], linewidth=2)

# Add labels and legend for RMSE
plt.xlabel('Epoch', fontsize=20)
plt.ylabel('RMSE Value', fontsize=20)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
y_min, y_max = plt.ylim()
plt.gca().spines['left'].set_bounds(y_min, y_max)
plt.gca().spines['bottom'].set_bounds(0, 100)

# Increase tick label size
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
plt.tight_layout(pad=2)
# Save the RMSE plot
#plt.savefig("C:\\Users\\HP\\Desktop\\New Ascend Results\\Mouse\\RMSE_plot.png", dpi = 1200)  # Update the path as needed

# Display the RMSE plot
plt.show()

# %%
#Fig 4 G

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data for the plot
tests = ['Test 1', 'Test 2', 'Test 3', 'Test 4', 'Test 5']
ccc_values = [0.9547467232, 0.9551003575, 0.9548706412, 0.9563142061, 0.952584]

# Calculate y-axis limits to emphasize differences
y_min = np.floor(min(ccc_values) * 1000) / 1000  # Rounding down to nearest 0.001
y_max = np.ceil(max(ccc_values) * 1000) / 1000  # Rounding up to nearest 0.001

# Plotting
sns.set(style="white")
plt.figure(figsize=(4, 4))
sns.barplot(x=tests, y=ccc_values, edgecolor="teal", fill=False)

# Adjust y-axis limits for better representation
plt.ylim(y_min, y_max)

# Adding labels, title, and customizing the style
plt.xlabel('Tests', fontsize=14)
plt.ylabel('CCC', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Development Test Data', fontsize=16)
sns.despine(right=True, top=True, offset=10, trim=True)

# Save the plot as an image
#output_path = r"C:\Users\HP\Downloads\DEVELOPMENT_TEST_CCC.png"
#plt.savefig(output_path, dpi=1200, bbox_inches='tight')

# Display the plot
plt.tight_layout()
plt.show()

# %%
#Fig 4 H

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data for the plot
tests = ['Test 1', 'Test 2', 'Test 3', 'Test 4', 'Test 5']
RMSE_values = [0.04700424895, 0.04688331857, 0.04704907909, 0.04635353386, 0.04792489111]

# Calculate y-axis limits to emphasize differences
y_min = np.floor(min(RMSE_values) * 1000) / 1000  # Rounding down to nearest 0.001
y_max = np.ceil(max(RMSE_values) * 1000) / 1000  # Rounding up to nearest 0.001

# Plotting
sns.set(style="white")
plt.figure(figsize=(4, 4))
sns.barplot(x=tests, y=RMSE_values, edgecolor="teal", fill=False)

# Adjust y-axis limits for better representation
plt.ylim(y_min, y_max)

# Adding labels, title, and customizing the style
plt.xlabel('Tests', fontsize=14)
plt.ylabel('RMSE', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Development Test Data', fontsize=16)
sns.despine(right=True, top=True, offset=10, trim=True)

# Save the plot as an image
#output_path = r"C:\Users\HP\Downloads\Development_TEST_RMSE.png"
#plt.savefig(output_path, dpi=1200, bbox_inches='tight')

# Display the plot
plt.tight_layout()
plt.show()

# %%
#Fig 4 I

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data for the plot
tests = ['ACSCeND', 'TAPE', 'Scaden', 'CIBERSORTx', 'EPIC', 'DWLS', 'Bisque']
ccc_values = [0.9381775856, 0.9301, 0.9262, 0.8581, 0.6572, 0.8018, 0.5799]

# Define unique edge colors for each test/tool
edge_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2']

# Calculate y-axis limits to emphasize differences
y_min = np.floor(min(ccc_values) * 1000) / 1000  # Rounding down to nearest 0.001
y_max = np.ceil(max(ccc_values) * 1000) / 1000  # Rounding up to nearest 0.001

# Plotting
sns.set(style="white")
plt.figure(figsize=(4, 4))

# Create barplot with individual edge colors
for i, (test, ccc, color) in enumerate(zip(tests, ccc_values, edge_colors)):
    plt.bar(i, ccc, edgecolor=color, color='none', linewidth=1.5)

# Adjust y-axis limits for better representation
plt.ylim(y_min, y_max)

# Adding labels, title, and customizing the style
plt.ylabel('CCC', fontsize=14)
plt.yticks(fontsize=14)
plt.title('Development Unseen Data', fontsize=16)

# Remove x-axis and x-tick labels
plt.xticks([])
plt.xlabel('')  # Removes x-axis label

# Add a legend
legend_handles = [plt.Line2D([0], [0], color='none', marker='s', markersize=10, 
                             markerfacecolor='none', markeredgecolor=color, linewidth=1.5, label=test) 
                  for test, color in zip(tests, edge_colors)]
plt.legend(handles=legend_handles, title="Tools", fontsize=10, title_fontsize=12, bbox_to_anchor=(1.05, 1), loc='upper left')

# Adjust spines and save the plot
sns.despine(right=True, top=True, offset=10, trim=True)
#output_path = r"C:\Users\HP\Downloads\Development_UNSEEN_CCC.png"
#plt.savefig(output_path, dpi=1200, bbox_inches='tight')

# Display the plot
plt.tight_layout()
plt.show()

# %%
#Fig 4 J

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data for the plot
tests = ['ACSCeND', 'TAPE', 'Scaden', 'CIBERSORTx', 'EPIC', 'DWLS', 'Bisque']
RMSE_values = [0.046049, 0.0616, 0.0585, 0.11467, 0.26723, 0.1471, 0.2918]

# Define unique edge colors for each test/tool
edge_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2']

# Calculate y-axis limits to emphasize differences
y_min = np.floor(min(RMSE_values) * 1000) / 1000  # Rounding down to nearest 0.001
y_max = np.ceil(max(RMSE_values) * 1000) / 1000  # Rounding up to nearest 0.001

# Plotting
sns.set(style="white")
plt.figure(figsize=(4, 4))

# Create barplot with individual edge colors
for i, (test, RMSE, color) in enumerate(zip(tests, RMSE_values, edge_colors)):
    plt.bar(i, RMSE, edgecolor=color, color='none', linewidth=1.5)

# Adjust y-axis limits for better representation
plt.ylim(y_min, y_max)

# Adding labels, title, and customizing the style
plt.ylabel('RMSE', fontsize=14)
plt.yticks(fontsize=14)
plt.title('Development Unseen Data', fontsize=16)

# Remove x-axis and x-tick labels
plt.xticks([])
plt.xlabel('')  # Removes x-axis label

# Add a legend
legend_handles = [plt.Line2D([0], [0], color='none', marker='s', markersize=10, 
                             markerfacecolor='none', markeredgecolor=color, linewidth=1.5, label=test) 
                  for test, color in zip(tests, edge_colors)]
plt.legend(handles=legend_handles, title="Tools", fontsize=10, title_fontsize=12, bbox_to_anchor=(1.05, 1), loc='upper left')

# Adjust spines and save the plot
sns.despine(right=True, top=True, offset=10, trim=True)
#output_path = r"C:\Users\HP\Downloads\Development_UNSEEN_RMSE.png"
#plt.savefig(output_path, dpi=1200, bbox_inches='tight')

# Display the plot
plt.tight_layout()
plt.show()

# %%
#Fig 4 L

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


predicted_gep = pd.read_csv("C:\\Users\\HP\\Downloads\\Development\\Development\\gep_pred.csv", index_col = 0)
signature_matrix = pd.read_csv("C:\\Users\\HP\\Downloads\\Development\\Development\\sig_pbmc.csv", index_col = 0)

# Create DataFrames
df_predicted = pd.DataFrame(predicted_gep)
df_signature = pd.DataFrame(signature_matrix)

# Combine the two matrices horizontally
combined_matrix = pd.concat([df_predicted, df_signature], axis=1)

# Compute the correlation matrix
correlation_matrix = combined_matrix.corr()

n=correlation_matrix.shape[0]
n1 = n/2
n1 = int(n1)
# Extract the lower right 10x10 portion
lower_right_10x10 = correlation_matrix.iloc[-n1:, -n1:]


plt.figure(figsize=(12, 10))
sns.heatmap(lower_right_10x10, cmap='YlGnBu', center=0, annot=False)

# Set titles and labels
plt.title('Heatmap of Predicted GEP and Signature Matrix Correlation', fontsize=20)
plt.xlabel('Predicted GEP', fontsize=20)
plt.ylabel('scRNAseq Ground Truth', fontsize=20)

# Remove tick labels
plt.xticks([])  # Remove x tick labels
plt.yticks([])  # Remove y tick labels

plt.tight_layout(pad=2)
plt.show()
